# %%
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from xgboost import XGBClassifier

from sklearn import preprocessing
from sklearn import svm
from sklearn import metrics

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split

# %%
# CSV 파일이 저장된 디렉토리 경로
directory = '../data'

# 디렉토리 내의 모든 파일 리스트를 가져옵니다
file_list = os.listdir(directory)

# "data_"가 포함된 CSV 파일들의 경로를 저장할 리스트
csv_files = []

# 파일 리스트를 순회하면서 "data_"가 포함된 CSV 파일을 찾습니다
for file in file_list:
    if file.endswith(".csv") and "data_" in file:
        csv_files.append(os.path.join(directory, file))

# CSV 파일들을 읽어서 DataFrame으로 저장합니다
df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)

# 결과 확인
df.head()
# Out:
#    No  Heartbeat  Temperature  Spo2  UserCode     GyroX     GyroY     GyroZ
# 0   1      108.0         36.6  95.0      33.0 -0.040861  4.985047  6.510526  \
# 1   2      109.0         36.7  99.0      33.0 -0.463092  4.372132  7.436710
# 2   3      111.0         36.6  98.0      33.0 -0.299648  4.603678  6.510526
# 3   4      108.0         36.6  97.0      33.0 -0.272407  4.481094  6.360703
# 4   5      110.0         36.6  98.0      33.0 -1.525479  5.175732  7.164303
#
#            Time       Label
# 0  4.960000e+13  Downstairs
# 1  4.960000e+13  Downstairs
# 2  4.960000e+13  Downstairs
# 3  4.960000e+13  Downstairs
# 4  4.960000e+13  Downstairs

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# No             0
# Heartbeat      1
# Temperature    1
# Spo2           1
# UserCode       1
# GyroX          1
# GyroY          1
# GyroZ          2
# Time           1
# Label          1
# dtype: int64

# %%
# 결측치가 삭제된 DataFrame 생성
df_cleaned = df.dropna()

# 결과 확인
print(df_cleaned)
# Out:
#              No  Heartbeat  Temperature  Spo2  UserCode     GyroX      GyroY
# 0             1      108.0         36.6  95.0      33.0 -0.040861   4.985047  \
# 1             2      109.0         36.7  99.0      33.0 -0.463092   4.372132
# 2             3      111.0         36.6  98.0      33.0 -0.299648   4.603678
# 3             4      108.0         36.6  97.0      33.0 -0.272407   4.481094
# 4             5      110.0         36.6  98.0      33.0 -1.525479   5.175732
# ...         ...        ...          ...   ...       ...       ...        ...
# 1048570  406772      128.0         36.6  99.0       7.0  5.520000   6.440000
# 1048571  406773      133.0         36.8  96.0       7.0  2.140000   8.470000
# 1048572  406774      131.0         36.7  95.0       7.0  6.090000   4.860000
# 1048573  406775      142.0         36.8  96.0       7.0  5.010000   9.700000
# 1048574  406776      136.0         36.6  96.0       7.0  4.140000  11.030000
#
#             GyroZ          Time       Label
# 0        6.510526  4.960000e+13  Downstairs
# 1        7.436710  4.960000e+13  Downstairs
# 2        6.510526  4.960000e+13  Downstairs
# 3        6.360703  4.960000e+13  Downstairs
# 4        7.164303  4.960000e+13  Downstairs
# ...           ...           ...         ...
# 1048570  0.460000  2.085590e+14     Walking
# 1048571 -0.380000  2.085590e+14     Walking
# 1048572  0.720000  2.085590e+14     Walking
# 1048573  0.340000  2.085590e+14     Walking
# 1048574  1.120000  2.085600e+14     Walking
#
# [1048574 rows x 10 columns]

# %%
# 특성과 타겟 데이터로 분할
X = df_cleaned[['Temperature','Heartbeat','GyroX','GyroY','GyroZ']]
y = df_cleaned['Label']

# 테스트 세트와 트레인 세트로 분할 (70% 트레인, 30% 테스트)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# 결과 확인
print("X_train:")
print(X_train)
print("y_train:")
print(y_train)
print("X_test:")
print(X_test)
print("y_test:")
print(y_test)
# Out:
# X_train:
#          Temperature  Heartbeat  GyroX  GyroY     GyroZ
# 593383          36.7      128.0  -2.60  13.53 -1.800000
# 1047394         36.6      133.0   2.87   8.24 -0.950000
# 357596          36.8      130.0   7.44  16.13 -5.240000
# 675228          36.6      136.0   9.58   8.54 -2.369940
# 428146          36.6      134.0  -4.33  -2.22  8.349273
# ...              ...        ...    ...    ...       ...
# 759363          36.7      130.0   2.18  15.05 -2.533385
# 535030          36.8      135.0   5.01  11.26  2.982856
# 573977          36.7      132.0  -1.84   5.63  4.399372
# 189636          36.7      133.0  -8.43  15.40 -0.994285
# 585903          36.7      142.0   7.70   5.22 -1.460000
#
# [734001 rows x 5 columns]
# y_train:
# 593383     Upstairs
# 1047394     Walking
# 357596      Jogging
# 675228      Walking
# 428146      Sitting
#              ...
# 759363      Walking
# 535030     Upstairs
# 573977     Upstairs
# 189636      Jogging
# 585903     Upstairs
# Name: Label, Length: 734001, dtype: object
# X_test:
#          Temperature  Heartbeat  GyroX  GyroY      GyroZ
# 497803          36.5      131.0   0.95   9.92   0.270000
# 522706          36.6      130.0  -7.93   5.75  -0.530000
# 704218          36.7      138.0   4.63   3.41   1.184970
# 857273          36.7      136.0   1.27  12.34  -3.260000
# 823617          36.6      130.0  -2.60  12.30  -0.299648
# ...              ...        ...    ...    ...        ...
# 566849          36.7      129.0  -0.19   5.94   2.029432
# 447727          36.6      136.0   1.57   5.90   7.930000
# 292881          36.8      130.0   3.41 -18.20   5.980000
# 1010645         36.7      129.0  -1.76  13.38   2.490000
# 287947          36.7      128.0   3.49   0.50 -13.910000
#
# [314573 rows x 5 columns]
# y_test:
# 497803     Standing
# 522706     Standing
# 704218      Walking
# 857273      Walking
# 823617      Walking
#              ...
# 566849     Upstairs
# 447727      Sitting
# 292881      Jogging
# 1010645     Walking
# 287947      Jogging
# Name: Label, Length: 314573, dtype: object

# %%
# 표준화
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
    for index, perplexity in enumerate(perplexities):
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('t-SNE을 활용한 시각화')
        df = pd.DataFrame({'x': X_reduced[:, 0], 'y': X_reduced[:, 1], 'label': y_data})
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, palette="Set1",
                   markers=['^', 'v', 's', 'o', '1', '2'])
        plt.title(f"perplexity : {perplexity} and max_iter : {n_iter}")
        img_name = img_name_prefix + f'_perp_{perplexity}_iter_{n_iter}.png'
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = X_train
y_pre_tsne = y_train
perform_tsne(X_data=X_pre_tsne, y_data=y_pre_tsne, perplexities=[20])
# Out:
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 734001 samples in 1.905s...
# [t-SNE] Computed neighbors for 734001 samples in 89.659s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 734001
# [t-SNE] Computed conditional probabilities for sample 2000 / 734001
# [t-SNE] Computed conditional probabilities for sample 3000 / 734001
# [t-SNE] Computed conditional probabilities for sample 4000 / 734001
# [t-SNE] Computed conditional probabilities for sample 5000 / 734001
# [t-SNE] Computed conditional probabilities for sample 6000 / 734001
# [t-SNE] Computed conditional probabilities for sample 7000 / 734001
# [t-SNE] Computed conditional probabilities for sample 8000 / 734001
# [t-SNE] Computed conditional probabilities for sample 9000 / 734001
# [t-SNE] Computed conditional probabilities for sample 10000 / 734001
# [t-SNE] Computed conditional probabilities for sample 11000 / 734001
# [t-SNE] Computed conditional probabilities for sample 12000 / 734001
# [t-SNE] Computed conditional probabilities for sample 13000 / 734001
# [t-SNE] Computed conditional probabilities for sample 14000 / 734001
# [t-SNE] Computed conditional probabilities for sample 15000 / 734001
# [t-SNE] Computed conditional probabilities for sample 16000 / 734001
# [t-SNE] Computed conditional probabilities for sample 17000 / 734001
# [t-SNE] Computed conditional probabilities for sample 18000 / 734001
# [t-SNE] Computed conditional probabilities for sample 19000 / 734001
# [t-SNE] Computed conditional probabilities for sample 20000 / 734001
# [t-SNE] Computed conditional probabilities for sample 21000 / 734001
# [t-SNE] Computed conditional probabilities for sample 22000 / 734001
# [t-SNE] Computed conditional probabilities for sample 23000 / 734001
# [t-SNE] Computed conditional probabilities for sample 24000 / 734001
# [t-SNE] Computed conditional probabilities for sample 25000 / 734001
# [t-SNE] Computed conditional probabilities for sample 26000 / 734001
# [t-SNE] Computed conditional probabilities for sample 27000 / 734001
# [t-SNE] Computed conditional probabilities for sample 28000 / 734001
# [t-SNE] Computed conditional probabilities for sample 29000 / 734001
# [t-SNE] Computed conditional probabilities for sample 30000 / 734001
# [t-SNE] Computed conditional probabilities for sample 31000 / 734001
# [t-SNE] Computed conditional probabilities for sample 32000 / 734001
# [t-SNE] Computed conditional probabilities for sample 33000 / 734001
# [t-SNE] Computed conditional probabilities for sample 34000 / 734001
# [t-SNE] Computed conditional probabilities for sample 35000 / 734001
# [t-SNE] Computed conditional probabilities for sample 36000 / 734001
# [t-SNE] Computed conditional probabilities for sample 37000 / 734001
# [t-SNE] Computed conditional probabilities for sample 38000 / 734001
# [t-SNE] Computed conditional probabilities for sample 39000 / 734001
# [t-SNE] Computed conditional probabilities for sample 40000 / 734001
# [t-SNE] Computed conditional probabilities for sample 41000 / 734001
# [t-SNE] Computed conditional probabilities for sample 42000 / 734001
# [t-SNE] Computed conditional probabilities for sample 43000 / 734001
# [t-SNE] Computed conditional probabilities for sample 44000 / 734001
# [t-SNE] Computed conditional probabilities for sample 45000 / 734001
# [t-SNE] Computed conditional probabilities for sample 46000 / 734001
# [t-SNE] Computed conditional probabilities for sample 47000 / 734001
# [t-SNE] Computed conditional probabilities for sample 48000 / 734001
# [t-SNE] Computed conditional probabilities for sample 49000 / 734001
# [t-SNE] Computed conditional probabilities for sample 50000 / 734001
# [t-SNE] Computed conditional probabilities for sample 51000 / 734001
# [t-SNE] Computed conditional probabilities for sample 52000 / 734001
# [t-SNE] Computed conditional probabilities for sample 53000 / 734001
# [t-SNE] Computed conditional probabilities for sample 54000 / 734001
# [t-SNE] Computed conditional probabilities for sample 55000 / 734001
# [t-SNE] Computed conditional probabilities for sample 56000 / 734001
# [t-SNE] Computed conditional probabilities for sample 57000 / 734001
# [t-SNE] Computed conditional probabilities for sample 58000 / 734001
# [t-SNE] Computed conditional probabilities for sample 59000 / 734001
# [t-SNE] Computed conditional probabilities for sample 60000 / 734001
# [t-SNE] Computed conditional probabilities for sample 61000 / 734001
# [t-SNE] Computed conditional probabilities for sample 62000 / 734001
# [t-SNE] Computed conditional probabilities for sample 63000 / 734001
# [t-SNE] Computed conditional probabilities for sample 64000 / 734001
# [t-SNE] Computed conditional probabilities for sample 65000 / 734001
# [t-SNE] Computed conditional probabilities for sample 66000 / 734001
# [t-SNE] Computed conditional probabilities for sample 67000 / 734001
# [t-SNE] Computed conditional probabilities for sample 68000 / 734001
# [t-SNE] Computed conditional probabilities for sample 69000 / 734001
# [t-SNE] Computed conditional probabilities for sample 70000 / 734001
# [t-SNE] Computed conditional probabilities for sample 71000 / 734001
# [t-SNE] Computed conditional probabilities for sample 72000 / 734001
# [t-SNE] Computed conditional probabilities for sample 73000 / 734001
# [t-SNE] Computed conditional probabilities for sample 74000 / 734001
# [t-SNE] Computed conditional probabilities for sample 75000 / 734001
# [t-SNE] Computed conditional probabilities for sample 76000 / 734001
# [t-SNE] Computed conditional probabilities for sample 77000 / 734001
# [t-SNE] Computed conditional probabilities for sample 78000 / 734001
# [t-SNE] Computed conditional probabilities for sample 79000 / 734001
# [t-SNE] Computed conditional probabilities for sample 80000 / 734001
# [t-SNE] Computed conditional probabilities for sample 81000 / 734001
# [t-SNE] Computed conditional probabilities for sample 82000 / 734001
# [t-SNE] Computed conditional probabilities for sample 83000 / 734001
# [t-SNE] Computed conditional probabilities for sample 84000 / 734001
# [t-SNE] Computed conditional probabilities for sample 85000 / 734001
# [t-SNE] Computed conditional probabilities for sample 86000 / 734001
# [t-SNE] Computed conditional probabilities for sample 87000 / 734001
# [t-SNE] Computed conditional probabilities for sample 88000 / 734001
# [t-SNE] Computed conditional probabilities for sample 89000 / 734001
# [t-SNE] Computed conditional probabilities for sample 90000 / 734001
# [t-SNE] Computed conditional probabilities for sample 91000 / 734001
# [t-SNE] Computed conditional probabilities for sample 92000 / 734001
# [t-SNE] Computed conditional probabilities for sample 93000 / 734001
# [t-SNE] Computed conditional probabilities for sample 94000 / 734001
# [t-SNE] Computed conditional probabilities for sample 95000 / 734001
# [t-SNE] Computed conditional probabilities for sample 96000 / 734001
# [t-SNE] Computed conditional probabilities for sample 97000 / 734001
# [t-SNE] Computed conditional probabilities for sample 98000 / 734001
# [t-SNE] Computed conditional probabilities for sample 99000 / 734001
# [t-SNE] Computed conditional probabilities for sample 100000 / 734001
# [t-SNE] Computed conditional probabilities for sample 101000 / 734001
# [t-SNE] Computed conditional probabilities for sample 102000 / 734001
# [t-SNE] Computed conditional probabilities for sample 103000 / 734001
# [t-SNE] Computed conditional probabilities for sample 104000 / 734001
# [t-SNE] Computed conditional probabilities for sample 105000 / 734001
# [t-SNE] Computed conditional probabilities for sample 106000 / 734001
# [t-SNE] Computed conditional probabilities for sample 107000 / 734001
# [t-SNE] Computed conditional probabilities for sample 108000 / 734001
# [t-SNE] Computed conditional probabilities for sample 109000 / 734001
# [t-SNE] Computed conditional probabilities for sample 110000 / 734001
# [t-SNE] Computed conditional probabilities for sample 111000 / 734001
# [t-SNE] Computed conditional probabilities for sample 112000 / 734001
# [t-SNE] Computed conditional probabilities for sample 113000 / 734001
# [t-SNE] Computed conditional probabilities for sample 114000 / 734001
# [t-SNE] Computed conditional probabilities for sample 115000 / 734001
# [t-SNE] Computed conditional probabilities for sample 116000 / 734001
# [t-SNE] Computed conditional probabilities for sample 117000 / 734001
# [t-SNE] Computed conditional probabilities for sample 118000 / 734001
# [t-SNE] Computed conditional probabilities for sample 119000 / 734001
# [t-SNE] Computed conditional probabilities for sample 120000 / 734001
# [t-SNE] Computed conditional probabilities for sample 121000 / 734001
# [t-SNE] Computed conditional probabilities for sample 122000 / 734001
# [t-SNE] Computed conditional probabilities for sample 123000 / 734001
# [t-SNE] Computed conditional probabilities for sample 124000 / 734001
# [t-SNE] Computed conditional probabilities for sample 125000 / 734001
# [t-SNE] Computed conditional probabilities for sample 126000 / 734001
# [t-SNE] Computed conditional probabilities for sample 127000 / 734001
# [t-SNE] Computed conditional probabilities for sample 128000 / 734001
# [t-SNE] Computed conditional probabilities for sample 129000 / 734001
# [t-SNE] Computed conditional probabilities for sample 130000 / 734001
# [t-SNE] Computed conditional probabilities for sample 131000 / 734001
# [t-SNE] Computed conditional probabilities for sample 132000 / 734001
# [t-SNE] Computed conditional probabilities for sample 133000 / 734001
# [t-SNE] Computed conditional probabilities for sample 134000 / 734001
# [t-SNE] Computed conditional probabilities for sample 135000 / 734001
# [t-SNE] Computed conditional probabilities for sample 136000 / 734001
# [t-SNE] Computed conditional probabilities for sample 137000 / 734001
# [t-SNE] Computed conditional probabilities for sample 138000 / 734001
# [t-SNE] Computed conditional probabilities for sample 139000 / 734001
# [t-SNE] Computed conditional probabilities for sample 140000 / 734001
# [t-SNE] Computed conditional probabilities for sample 141000 / 734001
# [t-SNE] Computed conditional probabilities for sample 142000 / 734001
# [t-SNE] Computed conditional probabilities for sample 143000 / 734001
# [t-SNE] Computed conditional probabilities for sample 144000 / 734001
# [t-SNE] Computed conditional probabilities for sample 145000 / 734001
# [t-SNE] Computed conditional probabilities for sample 146000 / 734001
# [t-SNE] Computed conditional probabilities for sample 147000 / 734001
# [t-SNE] Computed conditional probabilities for sample 148000 / 734001
# [t-SNE] Computed conditional probabilities for sample 149000 / 734001
# [t-SNE] Computed conditional probabilities for sample 150000 / 734001
# [t-SNE] Computed conditional probabilities for sample 151000 / 734001
# [t-SNE] Computed conditional probabilities for sample 152000 / 734001
# [t-SNE] Computed conditional probabilities for sample 153000 / 734001
# [t-SNE] Computed conditional probabilities for sample 154000 / 734001
# [t-SNE] Computed conditional probabilities for sample 155000 / 734001
# [t-SNE] Computed conditional probabilities for sample 156000 / 734001
# [t-SNE] Computed conditional probabilities for sample 157000 / 734001
# [t-SNE] Computed conditional probabilities for sample 158000 / 734001
# [t-SNE] Computed conditional probabilities for sample 159000 / 734001
# [t-SNE] Computed conditional probabilities for sample 160000 / 734001
# [t-SNE] Computed conditional probabilities for sample 161000 / 734001
# [t-SNE] Computed conditional probabilities for sample 162000 / 734001
# [t-SNE] Computed conditional probabilities for sample 163000 / 734001
# [t-SNE] Computed conditional probabilities for sample 164000 / 734001
# [t-SNE] Computed conditional probabilities for sample 165000 / 734001
# [t-SNE] Computed conditional probabilities for sample 166000 / 734001
# [t-SNE] Computed conditional probabilities for sample 167000 / 734001
# [t-SNE] Computed conditional probabilities for sample 168000 / 734001
# [t-SNE] Computed conditional probabilities for sample 169000 / 734001
# [t-SNE] Computed conditional probabilities for sample 170000 / 734001
# [t-SNE] Computed conditional probabilities for sample 171000 / 734001
# [t-SNE] Computed conditional probabilities for sample 172000 / 734001
# [t-SNE] Computed conditional probabilities for sample 173000 / 734001
# [t-SNE] Computed conditional probabilities for sample 174000 / 734001
# [t-SNE] Computed conditional probabilities for sample 175000 / 734001
# [t-SNE] Computed conditional probabilities for sample 176000 / 734001
# [t-SNE] Computed conditional probabilities for sample 177000 / 734001
# [t-SNE] Computed conditional probabilities for sample 178000 / 734001
# [t-SNE] Computed conditional probabilities for sample 179000 / 734001
# [t-SNE] Computed conditional probabilities for sample 180000 / 734001
# [t-SNE] Computed conditional probabilities for sample 181000 / 734001
# [t-SNE] Computed conditional probabilities for sample 182000 / 734001
# [t-SNE] Computed conditional probabilities for sample 183000 / 734001
# [t-SNE] Computed conditional probabilities for sample 184000 / 734001
# [t-SNE] Computed conditional probabilities for sample 185000 / 734001
# [t-SNE] Computed conditional probabilities for sample 186000 / 734001
# [t-SNE] Computed conditional probabilities for sample 187000 / 734001
# [t-SNE] Computed conditional probabilities for sample 188000 / 734001
# [t-SNE] Computed conditional probabilities for sample 189000 / 734001
# [t-SNE] Computed conditional probabilities for sample 190000 / 734001
# [t-SNE] Computed conditional probabilities for sample 191000 / 734001
# [t-SNE] Computed conditional probabilities for sample 192000 / 734001
# [t-SNE] Computed conditional probabilities for sample 193000 / 734001
# [t-SNE] Computed conditional probabilities for sample 194000 / 734001
# [t-SNE] Computed conditional probabilities for sample 195000 / 734001
# [t-SNE] Computed conditional probabilities for sample 196000 / 734001
# [t-SNE] Computed conditional probabilities for sample 197000 / 734001
# [t-SNE] Computed conditional probabilities for sample 198000 / 734001
# [t-SNE] Computed conditional probabilities for sample 199000 / 734001
# [t-SNE] Computed conditional probabilities for sample 200000 / 734001
# [t-SNE] Computed conditional probabilities for sample 201000 / 734001
# [t-SNE] Computed conditional probabilities for sample 202000 / 734001
# [t-SNE] Computed conditional probabilities for sample 203000 / 734001
# [t-SNE] Computed conditional probabilities for sample 204000 / 734001
# [t-SNE] Computed conditional probabilities for sample 205000 / 734001
# [t-SNE] Computed conditional probabilities for sample 206000 / 734001
# [t-SNE] Computed conditional probabilities for sample 207000 / 734001
# [t-SNE] Computed conditional probabilities for sample 208000 / 734001
# [t-SNE] Computed conditional probabilities for sample 209000 / 734001
# [t-SNE] Computed conditional probabilities for sample 210000 / 734001
# [t-SNE] Computed conditional probabilities for sample 211000 / 734001
# [t-SNE] Computed conditional probabilities for sample 212000 / 734001
# [t-SNE] Computed conditional probabilities for sample 213000 / 734001
# [t-SNE] Computed conditional probabilities for sample 214000 / 734001
# [t-SNE] Computed conditional probabilities for sample 215000 / 734001
# [t-SNE] Computed conditional probabilities for sample 216000 / 734001
# [t-SNE] Computed conditional probabilities for sample 217000 / 734001
# [t-SNE] Computed conditional probabilities for sample 218000 / 734001
# [t-SNE] Computed conditional probabilities for sample 219000 / 734001
# [t-SNE] Computed conditional probabilities for sample 220000 / 734001
# [t-SNE] Computed conditional probabilities for sample 221000 / 734001
# [t-SNE] Computed conditional probabilities for sample 222000 / 734001
# [t-SNE] Computed conditional probabilities for sample 223000 / 734001
# [t-SNE] Computed conditional probabilities for sample 224000 / 734001
# [t-SNE] Computed conditional probabilities for sample 225000 / 734001
# [t-SNE] Computed conditional probabilities for sample 226000 / 734001
# [t-SNE] Computed conditional probabilities for sample 227000 / 734001
# [t-SNE] Computed conditional probabilities for sample 228000 / 734001
# [t-SNE] Computed conditional probabilities for sample 229000 / 734001
# [t-SNE] Computed conditional probabilities for sample 230000 / 734001
# [t-SNE] Computed conditional probabilities for sample 231000 / 734001
# [t-SNE] Computed conditional probabilities for sample 232000 / 734001
# [t-SNE] Computed conditional probabilities for sample 233000 / 734001
# [t-SNE] Computed conditional probabilities for sample 234000 / 734001
# [t-SNE] Computed conditional probabilities for sample 235000 / 734001
# [t-SNE] Computed conditional probabilities for sample 236000 / 734001
# [t-SNE] Computed conditional probabilities for sample 237000 / 734001
# [t-SNE] Computed conditional probabilities for sample 238000 / 734001
# [t-SNE] Computed conditional probabilities for sample 239000 / 734001
# [t-SNE] Computed conditional probabilities for sample 240000 / 734001
# [t-SNE] Computed conditional probabilities for sample 241000 / 734001
# [t-SNE] Computed conditional probabilities for sample 242000 / 734001
# [t-SNE] Computed conditional probabilities for sample 243000 / 734001
# [t-SNE] Computed conditional probabilities for sample 244000 / 734001
# [t-SNE] Computed conditional probabilities for sample 245000 / 734001
# [t-SNE] Computed conditional probabilities for sample 246000 / 734001
# [t-SNE] Computed conditional probabilities for sample 247000 / 734001
# [t-SNE] Computed conditional probabilities for sample 248000 / 734001
# [t-SNE] Computed conditional probabilities for sample 249000 / 734001
# [t-SNE] Computed conditional probabilities for sample 250000 / 734001
# [t-SNE] Computed conditional probabilities for sample 251000 / 734001
# [t-SNE] Computed conditional probabilities for sample 252000 / 734001
# [t-SNE] Computed conditional probabilities for sample 253000 / 734001
# [t-SNE] Computed conditional probabilities for sample 254000 / 734001
# [t-SNE] Computed conditional probabilities for sample 255000 / 734001
# [t-SNE] Computed conditional probabilities for sample 256000 / 734001
# [t-SNE] Computed conditional probabilities for sample 257000 / 734001
# [t-SNE] Computed conditional probabilities for sample 258000 / 734001
# [t-SNE] Computed conditional probabilities for sample 259000 / 734001
# [t-SNE] Computed conditional probabilities for sample 260000 / 734001
# [t-SNE] Computed conditional probabilities for sample 261000 / 734001
# [t-SNE] Computed conditional probabilities for sample 262000 / 734001
# [t-SNE] Computed conditional probabilities for sample 263000 / 734001
# [t-SNE] Computed conditional probabilities for sample 264000 / 734001
# [t-SNE] Computed conditional probabilities for sample 265000 / 734001
# [t-SNE] Computed conditional probabilities for sample 266000 / 734001
# [t-SNE] Computed conditional probabilities for sample 267000 / 734001
# [t-SNE] Computed conditional probabilities for sample 268000 / 734001
# [t-SNE] Computed conditional probabilities for sample 269000 / 734001
# [t-SNE] Computed conditional probabilities for sample 270000 / 734001
# [t-SNE] Computed conditional probabilities for sample 271000 / 734001
# [t-SNE] Computed conditional probabilities for sample 272000 / 734001
# [t-SNE] Computed conditional probabilities for sample 273000 / 734001
# [t-SNE] Computed conditional probabilities for sample 274000 / 734001
# [t-SNE] Computed conditional probabilities for sample 275000 / 734001
# [t-SNE] Computed conditional probabilities for sample 276000 / 734001
# [t-SNE] Computed conditional probabilities for sample 277000 / 734001
# [t-SNE] Computed conditional probabilities for sample 278000 / 734001
# [t-SNE] Computed conditional probabilities for sample 279000 / 734001
# [t-SNE] Computed conditional probabilities for sample 280000 / 734001
# [t-SNE] Computed conditional probabilities for sample 281000 / 734001
# [t-SNE] Computed conditional probabilities for sample 282000 / 734001
# [t-SNE] Computed conditional probabilities for sample 283000 / 734001
# [t-SNE] Computed conditional probabilities for sample 284000 / 734001
# [t-SNE] Computed conditional probabilities for sample 285000 / 734001
# [t-SNE] Computed conditional probabilities for sample 286000 / 734001
# [t-SNE] Computed conditional probabilities for sample 287000 / 734001
# [t-SNE] Computed conditional probabilities for sample 288000 / 734001
# [t-SNE] Computed conditional probabilities for sample 289000 / 734001
# [t-SNE] Computed conditional probabilities for sample 290000 / 734001
# [t-SNE] Computed conditional probabilities for sample 291000 / 734001
# [t-SNE] Computed conditional probabilities for sample 292000 / 734001
# [t-SNE] Computed conditional probabilities for sample 293000 / 734001
# [t-SNE] Computed conditional probabilities for sample 294000 / 734001
# [t-SNE] Computed conditional probabilities for sample 295000 / 734001
# [t-SNE] Computed conditional probabilities for sample 296000 / 734001
# [t-SNE] Computed conditional probabilities for sample 297000 / 734001
# [t-SNE] Computed conditional probabilities for sample 298000 / 734001
# [t-SNE] Computed conditional probabilities for sample 299000 / 734001
# [t-SNE] Computed conditional probabilities for sample 300000 / 734001
# [t-SNE] Computed conditional probabilities for sample 301000 / 734001
# [t-SNE] Computed conditional probabilities for sample 302000 / 734001
# [t-SNE] Computed conditional probabilities for sample 303000 / 734001
# [t-SNE] Computed conditional probabilities for sample 304000 / 734001
# [t-SNE] Computed conditional probabilities for sample 305000 / 734001
# [t-SNE] Computed conditional probabilities for sample 306000 / 734001
# [t-SNE] Computed conditional probabilities for sample 307000 / 734001
# [t-SNE] Computed conditional probabilities for sample 308000 / 734001
# [t-SNE] Computed conditional probabilities for sample 309000 / 734001
# [t-SNE] Computed conditional probabilities for sample 310000 / 734001
# [t-SNE] Computed conditional probabilities for sample 311000 / 734001
# [t-SNE] Computed conditional probabilities for sample 312000 / 734001
# [t-SNE] Computed conditional probabilities for sample 313000 / 734001
# [t-SNE] Computed conditional probabilities for sample 314000 / 734001
# [t-SNE] Computed conditional probabilities for sample 315000 / 734001
# [t-SNE] Computed conditional probabilities for sample 316000 / 734001
# [t-SNE] Computed conditional probabilities for sample 317000 / 734001
# [t-SNE] Computed conditional probabilities for sample 318000 / 734001
# [t-SNE] Computed conditional probabilities for sample 319000 / 734001
# [t-SNE] Computed conditional probabilities for sample 320000 / 734001
# [t-SNE] Computed conditional probabilities for sample 321000 / 734001
# [t-SNE] Computed conditional probabilities for sample 322000 / 734001
# [t-SNE] Computed conditional probabilities for sample 323000 / 734001
# [t-SNE] Computed conditional probabilities for sample 324000 / 734001
# [t-SNE] Computed conditional probabilities for sample 325000 / 734001
# [t-SNE] Computed conditional probabilities for sample 326000 / 734001
# [t-SNE] Computed conditional probabilities for sample 327000 / 734001
# [t-SNE] Computed conditional probabilities for sample 328000 / 734001
# [t-SNE] Computed conditional probabilities for sample 329000 / 734001
# [t-SNE] Computed conditional probabilities for sample 330000 / 734001
# [t-SNE] Computed conditional probabilities for sample 331000 / 734001
# [t-SNE] Computed conditional probabilities for sample 332000 / 734001
# [t-SNE] Computed conditional probabilities for sample 333000 / 734001
# [t-SNE] Computed conditional probabilities for sample 334000 / 734001
# [t-SNE] Computed conditional probabilities for sample 335000 / 734001
# [t-SNE] Computed conditional probabilities for sample 336000 / 734001
# [t-SNE] Computed conditional probabilities for sample 337000 / 734001
# [t-SNE] Computed conditional probabilities for sample 338000 / 734001
# [t-SNE] Computed conditional probabilities for sample 339000 / 734001
# [t-SNE] Computed conditional probabilities for sample 340000 / 734001
# [t-SNE] Computed conditional probabilities for sample 341000 / 734001
# [t-SNE] Computed conditional probabilities for sample 342000 / 734001
# [t-SNE] Computed conditional probabilities for sample 343000 / 734001
# [t-SNE] Computed conditional probabilities for sample 344000 / 734001
# [t-SNE] Computed conditional probabilities for sample 345000 / 734001
# [t-SNE] Computed conditional probabilities for sample 346000 / 734001
# [t-SNE] Computed conditional probabilities for sample 347000 / 734001
# [t-SNE] Computed conditional probabilities for sample 348000 / 734001
# [t-SNE] Computed conditional probabilities for sample 349000 / 734001
# [t-SNE] Computed conditional probabilities for sample 350000 / 734001
# [t-SNE] Computed conditional probabilities for sample 351000 / 734001
# [t-SNE] Computed conditional probabilities for sample 352000 / 734001
# [t-SNE] Computed conditional probabilities for sample 353000 / 734001
# [t-SNE] Computed conditional probabilities for sample 354000 / 734001
# [t-SNE] Computed conditional probabilities for sample 355000 / 734001
# [t-SNE] Computed conditional probabilities for sample 356000 / 734001
# [t-SNE] Computed conditional probabilities for sample 357000 / 734001
# [t-SNE] Computed conditional probabilities for sample 358000 / 734001
# [t-SNE] Computed conditional probabilities for sample 359000 / 734001
# [t-SNE] Computed conditional probabilities for sample 360000 / 734001
# [t-SNE] Computed conditional probabilities for sample 361000 / 734001
# [t-SNE] Computed conditional probabilities for sample 362000 / 734001
# [t-SNE] Computed conditional probabilities for sample 363000 / 734001
# [t-SNE] Computed conditional probabilities for sample 364000 / 734001
# [t-SNE] Computed conditional probabilities for sample 365000 / 734001
# [t-SNE] Computed conditional probabilities for sample 366000 / 734001
# [t-SNE] Computed conditional probabilities for sample 367000 / 734001
# [t-SNE] Computed conditional probabilities for sample 368000 / 734001
# [t-SNE] Computed conditional probabilities for sample 369000 / 734001
# [t-SNE] Computed conditional probabilities for sample 370000 / 734001
# [t-SNE] Computed conditional probabilities for sample 371000 / 734001
# [t-SNE] Computed conditional probabilities for sample 372000 / 734001
# [t-SNE] Computed conditional probabilities for sample 373000 / 734001
# [t-SNE] Computed conditional probabilities for sample 374000 / 734001
# [t-SNE] Computed conditional probabilities for sample 375000 / 734001
# [t-SNE] Computed conditional probabilities for sample 376000 / 734001
# [t-SNE] Computed conditional probabilities for sample 377000 / 734001
# [t-SNE] Computed conditional probabilities for sample 378000 / 734001
# [t-SNE] Computed conditional probabilities for sample 379000 / 734001
# [t-SNE] Computed conditional probabilities for sample 380000 / 734001
# [t-SNE] Computed conditional probabilities for sample 381000 / 734001
# [t-SNE] Computed conditional probabilities for sample 382000 / 734001
# [t-SNE] Computed conditional probabilities for sample 383000 / 734001
# [t-SNE] Computed conditional probabilities for sample 384000 / 734001
# [t-SNE] Computed conditional probabilities for sample 385000 / 734001
# [t-SNE] Computed conditional probabilities for sample 386000 / 734001
# [t-SNE] Computed conditional probabilities for sample 387000 / 734001
# [t-SNE] Computed conditional probabilities for sample 388000 / 734001
# [t-SNE] Computed conditional probabilities for sample 389000 / 734001
# [t-SNE] Computed conditional probabilities for sample 390000 / 734001
# [t-SNE] Computed conditional probabilities for sample 391000 / 734001
# [t-SNE] Computed conditional probabilities for sample 392000 / 734001
# [t-SNE] Computed conditional probabilities for sample 393000 / 734001
# [t-SNE] Computed conditional probabilities for sample 394000 / 734001
# [t-SNE] Computed conditional probabilities for sample 395000 / 734001
# [t-SNE] Computed conditional probabilities for sample 396000 / 734001
# [t-SNE] Computed conditional probabilities for sample 397000 / 734001
# [t-SNE] Computed conditional probabilities for sample 398000 / 734001
# [t-SNE] Computed conditional probabilities for sample 399000 / 734001
# [t-SNE] Computed conditional probabilities for sample 400000 / 734001
# [t-SNE] Computed conditional probabilities for sample 401000 / 734001
# [t-SNE] Computed conditional probabilities for sample 402000 / 734001
# [t-SNE] Computed conditional probabilities for sample 403000 / 734001
# [t-SNE] Computed conditional probabilities for sample 404000 / 734001
# [t-SNE] Computed conditional probabilities for sample 405000 / 734001
# [t-SNE] Computed conditional probabilities for sample 406000 / 734001
# [t-SNE] Computed conditional probabilities for sample 407000 / 734001
# [t-SNE] Computed conditional probabilities for sample 408000 / 734001
# [t-SNE] Computed conditional probabilities for sample 409000 / 734001
# [t-SNE] Computed conditional probabilities for sample 410000 / 734001
# [t-SNE] Computed conditional probabilities for sample 411000 / 734001
# [t-SNE] Computed conditional probabilities for sample 412000 / 734001
# [t-SNE] Computed conditional probabilities for sample 413000 / 734001
# [t-SNE] Computed conditional probabilities for sample 414000 / 734001
# [t-SNE] Computed conditional probabilities for sample 415000 / 734001
# [t-SNE] Computed conditional probabilities for sample 416000 / 734001
# [t-SNE] Computed conditional probabilities for sample 417000 / 734001
# [t-SNE] Computed conditional probabilities for sample 418000 / 734001
# [t-SNE] Computed conditional probabilities for sample 419000 / 734001
# [t-SNE] Computed conditional probabilities for sample 420000 / 734001
# [t-SNE] Computed conditional probabilities for sample 421000 / 734001
# [t-SNE] Computed conditional probabilities for sample 422000 / 734001
# [t-SNE] Computed conditional probabilities for sample 423000 / 734001
# [t-SNE] Computed conditional probabilities for sample 424000 / 734001
# [t-SNE] Computed conditional probabilities for sample 425000 / 734001
# [t-SNE] Computed conditional probabilities for sample 426000 / 734001
# [t-SNE] Computed conditional probabilities for sample 427000 / 734001
# [t-SNE] Computed conditional probabilities for sample 428000 / 734001
# [t-SNE] Computed conditional probabilities for sample 429000 / 734001
# [t-SNE] Computed conditional probabilities for sample 430000 / 734001
# [t-SNE] Computed conditional probabilities for sample 431000 / 734001
# [t-SNE] Computed conditional probabilities for sample 432000 / 734001
# [t-SNE] Computed conditional probabilities for sample 433000 / 734001
# [t-SNE] Computed conditional probabilities for sample 434000 / 734001
# [t-SNE] Computed conditional probabilities for sample 435000 / 734001
# [t-SNE] Computed conditional probabilities for sample 436000 / 734001
# [t-SNE] Computed conditional probabilities for sample 437000 / 734001
# [t-SNE] Computed conditional probabilities for sample 438000 / 734001
# [t-SNE] Computed conditional probabilities for sample 439000 / 734001
# [t-SNE] Computed conditional probabilities for sample 440000 / 734001
# [t-SNE] Computed conditional probabilities for sample 441000 / 734001
# [t-SNE] Computed conditional probabilities for sample 442000 / 734001
# [t-SNE] Computed conditional probabilities for sample 443000 / 734001
# [t-SNE] Computed conditional probabilities for sample 444000 / 734001
# [t-SNE] Computed conditional probabilities for sample 445000 / 734001
# [t-SNE] Computed conditional probabilities for sample 446000 / 734001
# [t-SNE] Computed conditional probabilities for sample 447000 / 734001
# [t-SNE] Computed conditional probabilities for sample 448000 / 734001
# [t-SNE] Computed conditional probabilities for sample 449000 / 734001
# [t-SNE] Computed conditional probabilities for sample 450000 / 734001
# [t-SNE] Computed conditional probabilities for sample 451000 / 734001
# [t-SNE] Computed conditional probabilities for sample 452000 / 734001
# [t-SNE] Computed conditional probabilities for sample 453000 / 734001
# [t-SNE] Computed conditional probabilities for sample 454000 / 734001
# [t-SNE] Computed conditional probabilities for sample 455000 / 734001
# [t-SNE] Computed conditional probabilities for sample 456000 / 734001
# [t-SNE] Computed conditional probabilities for sample 457000 / 734001
# [t-SNE] Computed conditional probabilities for sample 458000 / 734001
# [t-SNE] Computed conditional probabilities for sample 459000 / 734001
# [t-SNE] Computed conditional probabilities for sample 460000 / 734001
# [t-SNE] Computed conditional probabilities for sample 461000 / 734001
# [t-SNE] Computed conditional probabilities for sample 462000 / 734001
# [t-SNE] Computed conditional probabilities for sample 463000 / 734001
# [t-SNE] Computed conditional probabilities for sample 464000 / 734001
# [t-SNE] Computed conditional probabilities for sample 465000 / 734001
# [t-SNE] Computed conditional probabilities for sample 466000 / 734001
# [t-SNE] Computed conditional probabilities for sample 467000 / 734001
# [t-SNE] Computed conditional probabilities for sample 468000 / 734001
# [t-SNE] Computed conditional probabilities for sample 469000 / 734001
# [t-SNE] Computed conditional probabilities for sample 470000 / 734001
# [t-SNE] Computed conditional probabilities for sample 471000 / 734001
# [t-SNE] Computed conditional probabilities for sample 472000 / 734001
# [t-SNE] Computed conditional probabilities for sample 473000 / 734001
# [t-SNE] Computed conditional probabilities for sample 474000 / 734001
# [t-SNE] Computed conditional probabilities for sample 475000 / 734001
# [t-SNE] Computed conditional probabilities for sample 476000 / 734001
# [t-SNE] Computed conditional probabilities for sample 477000 / 734001
# [t-SNE] Computed conditional probabilities for sample 478000 / 734001
# [t-SNE] Computed conditional probabilities for sample 479000 / 734001
# [t-SNE] Computed conditional probabilities for sample 480000 / 734001
# [t-SNE] Computed conditional probabilities for sample 481000 / 734001
# [t-SNE] Computed conditional probabilities for sample 482000 / 734001
# [t-SNE] Computed conditional probabilities for sample 483000 / 734001
# [t-SNE] Computed conditional probabilities for sample 484000 / 734001
# [t-SNE] Computed conditional probabilities for sample 485000 / 734001
# [t-SNE] Computed conditional probabilities for sample 486000 / 734001
# [t-SNE] Computed conditional probabilities for sample 487000 / 734001
# [t-SNE] Computed conditional probabilities for sample 488000 / 734001
# [t-SNE] Computed conditional probabilities for sample 489000 / 734001
# [t-SNE] Computed conditional probabilities for sample 490000 / 734001
# [t-SNE] Computed conditional probabilities for sample 491000 / 734001
# [t-SNE] Computed conditional probabilities for sample 492000 / 734001
# [t-SNE] Computed conditional probabilities for sample 493000 / 734001
# [t-SNE] Computed conditional probabilities for sample 494000 / 734001
# [t-SNE] Computed conditional probabilities for sample 495000 / 734001
# [t-SNE] Computed conditional probabilities for sample 496000 / 734001
# [t-SNE] Computed conditional probabilities for sample 497000 / 734001
# [t-SNE] Computed conditional probabilities for sample 498000 / 734001
# [t-SNE] Computed conditional probabilities for sample 499000 / 734001
# [t-SNE] Computed conditional probabilities for sample 500000 / 734001
# [t-SNE] Computed conditional probabilities for sample 501000 / 734001
# [t-SNE] Computed conditional probabilities for sample 502000 / 734001
# [t-SNE] Computed conditional probabilities for sample 503000 / 734001
# [t-SNE] Computed conditional probabilities for sample 504000 / 734001
# [t-SNE] Computed conditional probabilities for sample 505000 / 734001
# [t-SNE] Computed conditional probabilities for sample 506000 / 734001
# [t-SNE] Computed conditional probabilities for sample 507000 / 734001
# [t-SNE] Computed conditional probabilities for sample 508000 / 734001
# [t-SNE] Computed conditional probabilities for sample 509000 / 734001
# [t-SNE] Computed conditional probabilities for sample 510000 / 734001
# [t-SNE] Computed conditional probabilities for sample 511000 / 734001
# [t-SNE] Computed conditional probabilities for sample 512000 / 734001
# [t-SNE] Computed conditional probabilities for sample 513000 / 734001
# [t-SNE] Computed conditional probabilities for sample 514000 / 734001
# [t-SNE] Computed conditional probabilities for sample 515000 / 734001
# [t-SNE] Computed conditional probabilities for sample 516000 / 734001
# [t-SNE] Computed conditional probabilities for sample 517000 / 734001
# [t-SNE] Computed conditional probabilities for sample 518000 / 734001
# [t-SNE] Computed conditional probabilities for sample 519000 / 734001
# [t-SNE] Computed conditional probabilities for sample 520000 / 734001
# [t-SNE] Computed conditional probabilities for sample 521000 / 734001
# [t-SNE] Computed conditional probabilities for sample 522000 / 734001
# [t-SNE] Computed conditional probabilities for sample 523000 / 734001
# [t-SNE] Computed conditional probabilities for sample 524000 / 734001
# [t-SNE] Computed conditional probabilities for sample 525000 / 734001
# [t-SNE] Computed conditional probabilities for sample 526000 / 734001
# [t-SNE] Computed conditional probabilities for sample 527000 / 734001
# [t-SNE] Computed conditional probabilities for sample 528000 / 734001
# [t-SNE] Computed conditional probabilities for sample 529000 / 734001
# [t-SNE] Computed conditional probabilities for sample 530000 / 734001
# [t-SNE] Computed conditional probabilities for sample 531000 / 734001
# [t-SNE] Computed conditional probabilities for sample 532000 / 734001
# [t-SNE] Computed conditional probabilities for sample 533000 / 734001
# [t-SNE] Computed conditional probabilities for sample 534000 / 734001
# [t-SNE] Computed conditional probabilities for sample 535000 / 734001
# [t-SNE] Computed conditional probabilities for sample 536000 / 734001
# [t-SNE] Computed conditional probabilities for sample 537000 / 734001
# [t-SNE] Computed conditional probabilities for sample 538000 / 734001
# [t-SNE] Computed conditional probabilities for sample 539000 / 734001
# [t-SNE] Computed conditional probabilities for sample 540000 / 734001
# [t-SNE] Computed conditional probabilities for sample 541000 / 734001
# [t-SNE] Computed conditional probabilities for sample 542000 / 734001
# [t-SNE] Computed conditional probabilities for sample 543000 / 734001
# [t-SNE] Computed conditional probabilities for sample 544000 / 734001
# [t-SNE] Computed conditional probabilities for sample 545000 / 734001
# [t-SNE] Computed conditional probabilities for sample 546000 / 734001
# [t-SNE] Computed conditional probabilities for sample 547000 / 734001
# [t-SNE] Computed conditional probabilities for sample 548000 / 734001
# [t-SNE] Computed conditional probabilities for sample 549000 / 734001
# [t-SNE] Computed conditional probabilities for sample 550000 / 734001
# [t-SNE] Computed conditional probabilities for sample 551000 / 734001
# [t-SNE] Computed conditional probabilities for sample 552000 / 734001
# [t-SNE] Computed conditional probabilities for sample 553000 / 734001
# [t-SNE] Computed conditional probabilities for sample 554000 / 734001
# [t-SNE] Computed conditional probabilities for sample 555000 / 734001
# [t-SNE] Computed conditional probabilities for sample 556000 / 734001
# [t-SNE] Computed conditional probabilities for sample 557000 / 734001
# [t-SNE] Computed conditional probabilities for sample 558000 / 734001
# [t-SNE] Computed conditional probabilities for sample 559000 / 734001
# [t-SNE] Computed conditional probabilities for sample 560000 / 734001
# [t-SNE] Computed conditional probabilities for sample 561000 / 734001
# [t-SNE] Computed conditional probabilities for sample 562000 / 734001
# [t-SNE] Computed conditional probabilities for sample 563000 / 734001
# [t-SNE] Computed conditional probabilities for sample 564000 / 734001
# [t-SNE] Computed conditional probabilities for sample 565000 / 734001
# [t-SNE] Computed conditional probabilities for sample 566000 / 734001
# [t-SNE] Computed conditional probabilities for sample 567000 / 734001
# [t-SNE] Computed conditional probabilities for sample 568000 / 734001
# [t-SNE] Computed conditional probabilities for sample 569000 / 734001
# [t-SNE] Computed conditional probabilities for sample 570000 / 734001
# [t-SNE] Computed conditional probabilities for sample 571000 / 734001
# [t-SNE] Computed conditional probabilities for sample 572000 / 734001
# [t-SNE] Computed conditional probabilities for sample 573000 / 734001
# [t-SNE] Computed conditional probabilities for sample 574000 / 734001
# [t-SNE] Computed conditional probabilities for sample 575000 / 734001
# [t-SNE] Computed conditional probabilities for sample 576000 / 734001
# [t-SNE] Computed conditional probabilities for sample 577000 / 734001
# [t-SNE] Computed conditional probabilities for sample 578000 / 734001
# [t-SNE] Computed conditional probabilities for sample 579000 / 734001
# [t-SNE] Computed conditional probabilities for sample 580000 / 734001
# [t-SNE] Computed conditional probabilities for sample 581000 / 734001
# [t-SNE] Computed conditional probabilities for sample 582000 / 734001
# [t-SNE] Computed conditional probabilities for sample 583000 / 734001
# [t-SNE] Computed conditional probabilities for sample 584000 / 734001
# [t-SNE] Computed conditional probabilities for sample 585000 / 734001
# [t-SNE] Computed conditional probabilities for sample 586000 / 734001
# [t-SNE] Computed conditional probabilities for sample 587000 / 734001
# [t-SNE] Computed conditional probabilities for sample 588000 / 734001
# [t-SNE] Computed conditional probabilities for sample 589000 / 734001
# [t-SNE] Computed conditional probabilities for sample 590000 / 734001
# [t-SNE] Computed conditional probabilities for sample 591000 / 734001
# [t-SNE] Computed conditional probabilities for sample 592000 / 734001
# [t-SNE] Computed conditional probabilities for sample 593000 / 734001
# [t-SNE] Computed conditional probabilities for sample 594000 / 734001
# [t-SNE] Computed conditional probabilities for sample 595000 / 734001
# [t-SNE] Computed conditional probabilities for sample 596000 / 734001
# [t-SNE] Computed conditional probabilities for sample 597000 / 734001
# [t-SNE] Computed conditional probabilities for sample 598000 / 734001
# [t-SNE] Computed conditional probabilities for sample 599000 / 734001
# [t-SNE] Computed conditional probabilities for sample 600000 / 734001
# [t-SNE] Computed conditional probabilities for sample 601000 / 734001
# [t-SNE] Computed conditional probabilities for sample 602000 / 734001
# [t-SNE] Computed conditional probabilities for sample 603000 / 734001
# [t-SNE] Computed conditional probabilities for sample 604000 / 734001
# [t-SNE] Computed conditional probabilities for sample 605000 / 734001
# [t-SNE] Computed conditional probabilities for sample 606000 / 734001
# [t-SNE] Computed conditional probabilities for sample 607000 / 734001
# [t-SNE] Computed conditional probabilities for sample 608000 / 734001
# [t-SNE] Computed conditional probabilities for sample 609000 / 734001
# [t-SNE] Computed conditional probabilities for sample 610000 / 734001
# [t-SNE] Computed conditional probabilities for sample 611000 / 734001
# [t-SNE] Computed conditional probabilities for sample 612000 / 734001
# [t-SNE] Computed conditional probabilities for sample 613000 / 734001
# [t-SNE] Computed conditional probabilities for sample 614000 / 734001
# [t-SNE] Computed conditional probabilities for sample 615000 / 734001
# [t-SNE] Computed conditional probabilities for sample 616000 / 734001
# [t-SNE] Computed conditional probabilities for sample 617000 / 734001
# [t-SNE] Computed conditional probabilities for sample 618000 / 734001
# [t-SNE] Computed conditional probabilities for sample 619000 / 734001
# [t-SNE] Computed conditional probabilities for sample 620000 / 734001
# [t-SNE] Computed conditional probabilities for sample 621000 / 734001
# [t-SNE] Computed conditional probabilities for sample 622000 / 734001
# [t-SNE] Computed conditional probabilities for sample 623000 / 734001
# [t-SNE] Computed conditional probabilities for sample 624000 / 734001
# [t-SNE] Computed conditional probabilities for sample 625000 / 734001
# [t-SNE] Computed conditional probabilities for sample 626000 / 734001
# [t-SNE] Computed conditional probabilities for sample 627000 / 734001
# [t-SNE] Computed conditional probabilities for sample 628000 / 734001
# [t-SNE] Computed conditional probabilities for sample 629000 / 734001
# [t-SNE] Computed conditional probabilities for sample 630000 / 734001
# [t-SNE] Computed conditional probabilities for sample 631000 / 734001
# [t-SNE] Computed conditional probabilities for sample 632000 / 734001
# [t-SNE] Computed conditional probabilities for sample 633000 / 734001
# [t-SNE] Computed conditional probabilities for sample 634000 / 734001
# [t-SNE] Computed conditional probabilities for sample 635000 / 734001
# [t-SNE] Computed conditional probabilities for sample 636000 / 734001
# [t-SNE] Computed conditional probabilities for sample 637000 / 734001
# [t-SNE] Computed conditional probabilities for sample 638000 / 734001
# [t-SNE] Computed conditional probabilities for sample 639000 / 734001
# [t-SNE] Computed conditional probabilities for sample 640000 / 734001
# [t-SNE] Computed conditional probabilities for sample 641000 / 734001
# [t-SNE] Computed conditional probabilities for sample 642000 / 734001
# [t-SNE] Computed conditional probabilities for sample 643000 / 734001
# [t-SNE] Computed conditional probabilities for sample 644000 / 734001
# [t-SNE] Computed conditional probabilities for sample 645000 / 734001
# [t-SNE] Computed conditional probabilities for sample 646000 / 734001
# [t-SNE] Computed conditional probabilities for sample 647000 / 734001
# [t-SNE] Computed conditional probabilities for sample 648000 / 734001
# [t-SNE] Computed conditional probabilities for sample 649000 / 734001
# [t-SNE] Computed conditional probabilities for sample 650000 / 734001
# [t-SNE] Computed conditional probabilities for sample 651000 / 734001
# [t-SNE] Computed conditional probabilities for sample 652000 / 734001
# [t-SNE] Computed conditional probabilities for sample 653000 / 734001
# [t-SNE] Computed conditional probabilities for sample 654000 / 734001
# [t-SNE] Computed conditional probabilities for sample 655000 / 734001
# [t-SNE] Computed conditional probabilities for sample 656000 / 734001
# [t-SNE] Computed conditional probabilities for sample 657000 / 734001
# [t-SNE] Computed conditional probabilities for sample 658000 / 734001
# [t-SNE] Computed conditional probabilities for sample 659000 / 734001
# [t-SNE] Computed conditional probabilities for sample 660000 / 734001
# [t-SNE] Computed conditional probabilities for sample 661000 / 734001
# [t-SNE] Computed conditional probabilities for sample 662000 / 734001
# [t-SNE] Computed conditional probabilities for sample 663000 / 734001
# [t-SNE] Computed conditional probabilities for sample 664000 / 734001
# [t-SNE] Computed conditional probabilities for sample 665000 / 734001
# [t-SNE] Computed conditional probabilities for sample 666000 / 734001
# [t-SNE] Computed conditional probabilities for sample 667000 / 734001
# [t-SNE] Computed conditional probabilities for sample 668000 / 734001
# [t-SNE] Computed conditional probabilities for sample 669000 / 734001
# [t-SNE] Computed conditional probabilities for sample 670000 / 734001
# [t-SNE] Computed conditional probabilities for sample 671000 / 734001
# [t-SNE] Computed conditional probabilities for sample 672000 / 734001
# [t-SNE] Computed conditional probabilities for sample 673000 / 734001
# [t-SNE] Computed conditional probabilities for sample 674000 / 734001
# [t-SNE] Computed conditional probabilities for sample 675000 / 734001
# [t-SNE] Computed conditional probabilities for sample 676000 / 734001
# [t-SNE] Computed conditional probabilities for sample 677000 / 734001
# [t-SNE] Computed conditional probabilities for sample 678000 / 734001
# [t-SNE] Computed conditional probabilities for sample 679000 / 734001
# [t-SNE] Computed conditional probabilities for sample 680000 / 734001
# [t-SNE] Computed conditional probabilities for sample 681000 / 734001
# [t-SNE] Computed conditional probabilities for sample 682000 / 734001
# [t-SNE] Computed conditional probabilities for sample 683000 / 734001
# [t-SNE] Computed conditional probabilities for sample 684000 / 734001
# [t-SNE] Computed conditional probabilities for sample 685000 / 734001
# [t-SNE] Computed conditional probabilities for sample 686000 / 734001
# [t-SNE] Computed conditional probabilities for sample 687000 / 734001
# [t-SNE] Computed conditional probabilities for sample 688000 / 734001
# [t-SNE] Computed conditional probabilities for sample 689000 / 734001
# [t-SNE] Computed conditional probabilities for sample 690000 / 734001
# [t-SNE] Computed conditional probabilities for sample 691000 / 734001
# [t-SNE] Computed conditional probabilities for sample 692000 / 734001
# [t-SNE] Computed conditional probabilities for sample 693000 / 734001
# [t-SNE] Computed conditional probabilities for sample 694000 / 734001
# [t-SNE] Computed conditional probabilities for sample 695000 / 734001
# [t-SNE] Computed conditional probabilities for sample 696000 / 734001
# [t-SNE] Computed conditional probabilities for sample 697000 / 734001
# [t-SNE] Computed conditional probabilities for sample 698000 / 734001
# [t-SNE] Computed conditional probabilities for sample 699000 / 734001
# [t-SNE] Computed conditional probabilities for sample 700000 / 734001
# [t-SNE] Computed conditional probabilities for sample 701000 / 734001
# [t-SNE] Computed conditional probabilities for sample 702000 / 734001
# [t-SNE] Computed conditional probabilities for sample 703000 / 734001
# [t-SNE] Computed conditional probabilities for sample 704000 / 734001
# [t-SNE] Computed conditional probabilities for sample 705000 / 734001
# [t-SNE] Computed conditional probabilities for sample 706000 / 734001
# [t-SNE] Computed conditional probabilities for sample 707000 / 734001
# [t-SNE] Computed conditional probabilities for sample 708000 / 734001
# [t-SNE] Computed conditional probabilities for sample 709000 / 734001
# [t-SNE] Computed conditional probabilities for sample 710000 / 734001
# [t-SNE] Computed conditional probabilities for sample 711000 / 734001
# [t-SNE] Computed conditional probabilities for sample 712000 / 734001
# [t-SNE] Computed conditional probabilities for sample 713000 / 734001
# [t-SNE] Computed conditional probabilities for sample 714000 / 734001
# [t-SNE] Computed conditional probabilities for sample 715000 / 734001
# [t-SNE] Computed conditional probabilities for sample 716000 / 734001
# [t-SNE] Computed conditional probabilities for sample 717000 / 734001
# [t-SNE] Computed conditional probabilities for sample 718000 / 734001
# [t-SNE] Computed conditional probabilities for sample 719000 / 734001
# [t-SNE] Computed conditional probabilities for sample 720000 / 734001
# [t-SNE] Computed conditional probabilities for sample 721000 / 734001
# [t-SNE] Computed conditional probabilities for sample 722000 / 734001
# [t-SNE] Computed conditional probabilities for sample 723000 / 734001
# [t-SNE] Computed conditional probabilities for sample 724000 / 734001
# [t-SNE] Computed conditional probabilities for sample 725000 / 734001
# [t-SNE] Computed conditional probabilities for sample 726000 / 734001
# [t-SNE] Computed conditional probabilities for sample 727000 / 734001
# [t-SNE] Computed conditional probabilities for sample 728000 / 734001
# [t-SNE] Computed conditional probabilities for sample 729000 / 734001
# [t-SNE] Computed conditional probabilities for sample 730000 / 734001
# [t-SNE] Computed conditional probabilities for sample 731000 / 734001
# [t-SNE] Computed conditional probabilities for sample 732000 / 734001
# [t-SNE] Computed conditional probabilities for sample 733000 / 734001
# [t-SNE] Computed conditional probabilities for sample 734000 / 734001
# [t-SNE] Computed conditional probabilities for sample 734001 / 734001
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Computed conditional probabilities in 12.445s
# [t-SNE] Iteration 50: error = 135.6534882, gradient norm = 0.0035819 (50 iterations in 200.306s)
# [t-SNE] Iteration 100: error = 126.6525421, gradient norm = 0.0013301 (50 iterations in 156.085s)
# [t-SNE] Iteration 150: error = 123.0946732, gradient norm = 0.0009769 (50 iterations in 168.698s)
# [t-SNE] Iteration 200: error = 121.0261612, gradient norm = 0.0007947 (50 iterations in 176.309s)
# [t-SNE] Iteration 250: error = 119.5664444, gradient norm = 0.0006721 (50 iterations in 186.166s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 119.566444
# [t-SNE] Iteration 300: error = 6.6340723, gradient norm = 0.0016507 (50 iterations in 184.248s)
# [t-SNE] Iteration 350: error = 5.8540144, gradient norm = 0.0018133 (50 iterations in 177.381s)
# [t-SNE] Iteration 400: error = 5.3358312, gradient norm = 0.0018487 (50 iterations in 150.513s)
# [t-SNE] Iteration 450: error = 4.9676757, gradient norm = 0.0018164 (50 iterations in 142.538s)
# [t-SNE] Iteration 500: error = 4.6998324, gradient norm = 0.0016179 (50 iterations in 141.394s)
# [t-SNE] Iteration 550: error = 4.5104656, gradient norm = 0.0014453 (50 iterations in 139.610s)
# [t-SNE] Iteration 600: error = 4.3646793, gradient norm = 0.0013110 (50 iterations in 147.882s)
# [t-SNE] Iteration 650: error = 4.2447119, gradient norm = 0.0012013 (50 iterations in 179.308s)
# [t-SNE] Iteration 700: error = 4.1464148, gradient norm = 0.0011172 (50 iterations in 166.356s)
# [t-SNE] Iteration 750: error = 4.0614576, gradient norm = 0.0010437 (50 iterations in 174.789s)
# [t-SNE] Iteration 800: error = 3.9883094, gradient norm = 0.0009830 (50 iterations in 173.247s)
# [t-SNE] Iteration 850: error = 3.9222836, gradient norm = 0.0009316 (50 iterations in 181.199s)
# [t-SNE] Iteration 900: error = 3.8632367, gradient norm = 0.0008861 (50 iterations in 169.760s)
# [t-SNE] Iteration 950: error = 3.8016713, gradient norm = 0.0008489 (50 iterations in 162.578s)
# [t-SNE] Iteration 1000: error = 3.7515047, gradient norm = 0.0008148 (50 iterations in 159.245s)
# [t-SNE] KL divergence after 1000 iterations: 3.751505
# t-SNE을 활용한 시각화
# Done

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def perform_tsne_3d(X_data, y_data, perplexities):
    tsne = TSNE(n_components=3, random_state=42)
    X_tsne = tsne.fit_transform(X_data)

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    y_colors = np.unique(y_data)
    y_numeric = np.arange(len(y_colors))
    y_data_numeric = np.zeros_like(y_data)
    for i, color in enumerate(y_colors):
        y_data_numeric[y_data == color] = y_numeric[i]

    for perplexity in perplexities:
        ax.scatter(X_tsne[:, 0], X_tsne[:, 1], X_tsne[:, 2], c=y_data_numeric, cmap='viridis', label=perplexity)

    ax.set_xlabel('TSNE Component 1')
    ax.set_ylabel('TSNE Component 2')
    ax.set_zlabel('TSNE Component 3')
    ax.set_title('t-SNE 3D Visualization')
    ax.legend()

    plt.show()

# 3차원 t-SNE 시각화 실행
X_pre_tsne = X_train
y_pre_tsne = y_train
perform_tsne_3d(X_data=X_pre_tsne, y_data=y_pre_tsne, perplexities=[20])
